# %% [markdown]
# <a href="https://colab.research.google.com/github/snehalsandy/examples/blob/master/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import pandas_profiling as pp
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import f1_score, precision_score, recall_score

# %%
df=pd.read_csv("/content/sample_data/musk_csv.csv")

# %%
df.head()
# Out:
#    ID molecule_name conformation_name  f1   f2  ...  f163  f164  f165  f166  class
# 0   1      MUSK-211           211_1+1  46 -108  ...   156   -50  -112    96      1
# 1   2      MUSK-211          211_1+10  41 -188  ...   169   -61  -136    79      1
# 2   3      MUSK-211          211_1+11  46 -194  ...   165   -67  -145    39      1
# 3   4      MUSK-211          211_1+12  41 -188  ...   168   -60  -135    80      1
# 4   5      MUSK-211          211_1+13  41 -188  ...   168   -60  -135    80      1
#
# [5 rows x 170 columns]

# %%
df.shape
# Out:
# (6598, 170)

# %%
df.isna().sum()
# Out:
# ID                   0
# molecule_name        0
# conformation_name    0
# f1                   0
# f2                   0
#                     ..
# f163                 0
# f164                 0
# f165                 0
# f166                 0
# class                0
# Length: 170, dtype: int64

# %%
corr_matrix = df.corr().abs()

# %%
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

to_drop = [column for column in upper.columns if any(upper[column] > 0.92)]

# %%
dd = df.drop(columns = to_drop)

# %%
dd
# Out:
#         ID  molecule_name conformation_name  f1  ...  f164  f165  f166  class
# 0        1       MUSK-211           211_1+1  46  ...   -50  -112    96      1
# 1        2       MUSK-211          211_1+10  41  ...   -61  -136    79      1
# 2        3       MUSK-211          211_1+11  46  ...   -67  -145    39      1
# 3        4       MUSK-211          211_1+12  41  ...   -60  -135    80      1
# 4        5       MUSK-211          211_1+13  41  ...   -60  -135    80      1
# ...    ...            ...               ...  ..  ...   ...   ...   ...    ...
# 6593  6594  NON-MUSK-jp13          jp13_2+5  51  ...   -44  -115   118      0
# 6594  6595  NON-MUSK-jp13          jp13_2+6  44  ...   -66  -144    -5      0
# 6595  6596  NON-MUSK-jp13          jp13_2+7  44  ...   -66  -144    -6      0
# 6596  6597  NON-MUSK-jp13          jp13_2+8  51  ...   -44  -116   117      0
# 6597  6598  NON-MUSK-jp13          jp13_2+9  51  ...   -44  -115   118      0
#
# [6598 rows x 117 columns]

# %%
dd.shape
# Out:
# (6598, 117)

# %%
train,test = train_test_split(dd, random_state=30, test_size = 0.2)
Xtrain = train.iloc[:,3:-1]
Ytrain = train.iloc[:,-1:]
Xtest = test.iloc[:,3:-1]
Ytest = test.iloc[:,-1:]
Xtrain.shape
# Out:
# (5278, 113)

# %%
import tensorflow as tf

# %%
a=[1]*Xtrain.shape[0]
Xtrain["demo"]=a
Xtrain.shape
# Out:
# (5278, 114)

# %%
b=[1]*Xtest.shape[0]
Xtest["demo"]=b
Xtest.shape
# Out:
# (1320, 114)

# %%
x_train=Xtrain.values.reshape(Xtrain.shape[0],19,6,1)
x_test=Xtest.values.reshape(Xtest.shape[0],19,6,1)

# %%
x_train.shape
# Out:
# (5278, 19, 6, 1)

# %%
x_test.shape
# Out:
# (1320, 19, 6, 1)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D

# %%
model=Sequential()
model.add(Conv2D(32,kernel_size=(3,3),activation='relu',input_shape=(19,6,1)))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss=keras.losses.binary_crossentropy,optimizer=keras.optimizers.Adadelta(),metrics=['accuracy'])

# %%
history = model.fit(x_train,Ytrain,batch_size=128,epochs=150,validation_data=(x_test,Ytest))
score=model.evaluate(x_test,Ytest,verbose=0)
print(score)
# Out:
# Epoch 1/150
# 42/42 [==============================] - 1s 25ms/step - loss: 3.8398 - accuracy: 0.7736 - val_loss: 1.5204 - val_accuracy: 0.8561
# Epoch 2/150
# 42/42 [==============================] - 1s 23ms/step - loss: 3.8750 - accuracy: 0.7730 - val_loss: 1.5090 - val_accuracy: 0.8553
# Epoch 3/150
# 42/42 [==============================] - 1s 22ms/step - loss: 3.7689 - accuracy: 0.7755 - val_loss: 1.4769 - val_accuracy: 0.8568
# Epoch 4/150
# 42/42 [==============================] - 1s 24ms/step - loss: 3.8299 - accuracy: 0.7766 - val_loss: 1.4468 - val_accuracy: 0.8591
# Epoch 5/150
# 42/42 [==============================] - 1s 25ms/step - loss: 3.9042 - accuracy: 0.7728 - val_loss: 1.4292 - val_accuracy: 0.8606
# Epoch 6/150
# 42/42 [==============================] - 1s 23ms/step - loss: 3.7865 - accuracy: 0.7745 - val_loss: 1.3906 - val_accuracy: 0.8614
# Epoch 7/150
# ...

# %%
# %matplotlib inline

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
print("f1_score:",f1_score(Ytest,model.predict_classes(x_test),))
print("recall:",recall_score(Ytest,model.predict_classes(x_test),))
print("Validation Loss:",score[0])
print("Validation Accuracy:",score[1])
# Out:
# f1_score: 0.6188925081433224
# recall: 0.49222797927461137
# Validation Loss: 0.48022547364234924
# Validation Accuracy: 0.9113636612892151

# %%
model.save('/content/sample_data/model2.h5')
